# %%
class MyComplexNumber:
  # Constructor methods
  def __init__(self,real=0,imag=0):
    print("MyComplexNumer constructor executing...")
    self.real_part = real
    self.imag_part = imag

  def displayComplex(self):
    print("{0} + {1}j".format(self.real_part,self.imag_part))

# %%
# create new object against MyComplexNumber class
cmplx1 = MyComplexNumber(40,50)

# calling displayComplex() function
# output 40 + 50j
cmplx1.displayComplex()
# Out:
# MyComplexNumer constructor executing...
# 40 + 50j

# %%
cmplx2 = MyComplexNumber(60,70)
cmplx2.new_attribute = 80
cmplx2.displayComplex()
# output: (60,70,80)
print((cmplx2.real_part,cmplx2.imag_part,cmplx2.new_attribute))
# Out:
# MyComplexNumer constructor executing...
# 60 + 70j
# (60, 70, 80)

# %%
# cmplx1 object doesn't have attribute = 'new_attribute'
# AttributeError: 'MyComplexNumer' object has no attribute 'new_attribute'
cmplx1.new_attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-33eea276ddd5> in <cell line: 3>()
#       1 # cmplx1 object doesn't have attribute = 'new_attribute'
#       2 # AttributeError: 'MyComplexNumer' object has no attribute 'new_attribute'
# ----> 3 cmplx1.new_attribute
#
# AttributeError: 'MyComplexNumber' object has no attribute 'new_attribute'

# %%
# deleting object attributes and the object
print(cmplx1)
del cmplx1.real_part
del cmplx1
# Out:
# <__main__.MyComplexNumber object at 0x7bcd6d0137c0>

# %%
print(cmplx1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1724591c7af0> in <cell line: 1>()
# ----> 1 print(cmplx1)
#
# NameError: name 'cmplx1' is not defined
