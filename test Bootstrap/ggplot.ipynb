# %%
#pip install dplython
# Out:
# Collecting dplython
#   Downloading dplython-0.0.7.tar.gz (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.7/715.7 kB 2.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from dplython) (1.26.3)
# Requirement already satisfied: pandas in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from dplython) (2.2.0)
# Requirement already satisfied: six in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from dplython) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from pandas->dplython) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from pandas->dplython) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from pandas->dplython) (2023.4)
# Building wheels for collected packages: dplython
#   Building wheel for dplython (setup.py) ... done
#   Created wheel for dplython: filename=dplython-0.0.7-py3-none-any.whl size=747226 sha256=a6493514e2fba38bddc8a310aceaaa7a5b8ea7d92aa29b5eb4fccfc19902f134
#   Stored in directory: /Users/sergionava/Library/Caches/pip/wheels/7f/e8/a7/4b60ecd147fb2d8e9f00be68de9c36195a334b34c32546ee2b
# Successfully built dplython
# Installing collected packages: dplython
# Successfully installed dplython-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas
from dplython import (DplyFrame, X, diamonds, select, sift, sample_n,
    sample_frac, head, arrange, mutate, group_by, summarize, DelayFunction)
# Out:
# /var/folders/pd/p87_fpld3mb88drr5w_5mhb00000gn/T/ipykernel_97411/1494407029.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas

# %%
diamondsSmall = diamonds >> select(X.carat, X.cut, X.price, X.color, X.clarity  , X.depth  , X.table)
# Out:
# /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:706: DeprecationWarning: Passing a BlockManager to DplyFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:706: DeprecationWarning: Passing a BlockManager to DplyFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(

# %%
print(diamondsSmall >> head)
# Out:
#    carat      cut  price color clarity  depth  table
# 0   0.23    Ideal    326     E     SI2   61.5   55.0
# 1   0.21  Premium    326     E     SI1   59.8   61.0
# 2   0.23     Good    327     E     VS1   56.9   65.0
# 3   0.29  Premium    334     I     VS2   62.4   58.0
# 4   0.31     Good    335     J     SI2   63.3   58.0
# /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:706: DeprecationWarning: Passing a BlockManager to DplyFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(

# %%
print((diamondsSmall >> sift(X.price > 18000, X.carat < 1.2) >> arrange(X.depth)))
# Out:
#        carat        cut  price color clarity  depth  table
# 27455   1.14  Very Good  18112     D      IF   59.1   58.0
# 27457   1.07  Very Good  18114     D      IF   60.9   58.0
# 27530   1.07    Premium  18279     D      IF   60.9   58.0
# 27635   1.04  Very Good  18542     D      IF   61.3   56.0
# 27507   1.09  Very Good  18231     D      IF   61.7   58.0
# /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:706: DeprecationWarning: Passing a BlockManager to DplyFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:706: DeprecationWarning: Passing a BlockManager to DplyFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(

# %%
pip install plotnine
# Out:
# Collecting plotnine
#   Downloading plotnine-0.12.4-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: matplotlib>=3.6.0 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from plotnine) (3.8.2)
# Collecting mizani<0.10.0,>0.9.0 (from plotnine)
#   Downloading mizani-0.9.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: numpy>=1.23.0 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from plotnine) (1.26.3)
# Requirement already satisfied: pandas>=1.5.0 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from plotnine) (2.2.0)
# Collecting patsy>=0.5.1 (from plotnine)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: scipy>=1.5.0 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from plotnine) (1.11.4)
# Collecting statsmodels>=0.14.0 (from plotnine)
#   Downloading statsmodels-0.14.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from matplotlib>=3.6.0->plotnine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from pandas>=1.5.0->plotnine) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from pandas>=1.5.0->plotnine) (2023.4)
# Requirement already satisfied: six in /Users/sergionava/opt/anaconda3/envs/py311/lib/python3.11/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Downloading plotnine-0.12.4-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.2 MB/s eta 0:00:00a 0:00:010m
# Downloading mizani-0.9.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 4.9 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 13.7 MB/s eta 0:00:00
# Downloading statsmodels-0.14.1-cp311-cp311-macosx_10_9_x86_64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 14.6 MB/s eta 0:00:0000:010:01
# Installing collected packages: patsy, statsmodels, mizani, plotnine
# Successfully installed mizani-0.9.3 patsy-0.5.6 plotnine-0.12.4 statsmodels-0.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings; warnings.filterwarnings("ignore") # hide Python warnings 
import pandas
import dplython as dplython
from plotnine import *
diamondsSample = dplython.diamonds >> dplython.sample_n(5000)

# %%
print(ggplot(diamondsSample) # diamondsSample is the data  
 + aes('carat', 'price') # plot 'carat' vs 'price'
 + geom_point() # display the results as a scatter plot
 )

# %%
print(ggplot(diamondsSample)  
 + aes('carat', 'price') 
 + stat_smooth() # add a line of best fit
 + geom_point())

# %%
print(ggplot(diamondsSample)
 + aes('carat', 'price')
 + aes(color='cut') # colour the data by the variable cut and create a ledgend 
 + geom_point())

# %%
print(ggplot(diamondsSample)
 + aes('carat', 'price')
 + aes(color='cut')
 + facet_wrap('color') # seperate the data by 'colour' and graph seperately  
 + geom_point())
