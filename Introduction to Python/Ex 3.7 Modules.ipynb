# %%
# Importing module as well as renaming it
import math as m
print("The value of pi es",m.pi)
# Out:
# The value of pi es 3.141592653589793

# %%
# Use of from
from math import pi
print("The value of pi es",pi)
# Out:
# The value of pi es 3.141592653589793

# %%
# Import all names from the standard module math
from math import *
print("The value of pi es",pi)
# Out:
# The value of pi es 3.141592653589793
