# %%
# scope
def outer_function():
  global a
  a = 20

  def inner_function():
    global a
    a = 30
    print("a =", a)

  inner_function()
  print("a =", a)

a = 10
print("a =", a)
outer_function()
print("a =", a)
# Out:
# a = 10
# a = 30
# a = 30
# a = 30
